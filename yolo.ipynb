# %%
from ultralytics import YOLO

# %%
model = YOLO("ml/models/yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 13.4MB/s]

# %%
model.track("./assets/test.mp4")
# Out:
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# ...
#   Obtaining dependency information for lapx>=0.5.2 from https://files.pythonhosted.org/packages/8e/08/84ac2a69c759da1d50743c3f5ffe94f713564110d9039972374f6cd8b22d/lapx-0.5.5-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for Cython>=0.29.32 from https://files.pythonhosted.org/packages/39/5d/5ae976df4e368327864917a24f9dee7c8176de1b5b7044ee9903b8adb07a/Cython-3.0.3-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 1.5/1.5 MB 3.2 MB/s eta 0:00:0002
# ...
#    ---------------------------------------- 2.8/2.8 MB 6.6 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success  7.3s, installed 1 package: ['lapx>=0.5.2']
# requirements:  Restart runtime or rerun command for updates to take effect
#
#
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# ...
